# %% [markdown]
# <a href="https://colab.research.google.com/github/gagan3754/-Netflix---Data-Exploration-and-Visualisation/blob/main/Netflix_Data_Analysis_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#
# # Netflix Data Analysis
#
# <img src="https://media.tenor.com/QJNoPeq9WmUAAAAC/netflix-intro-netflix.gif">

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading Dataset

# %%
df=pd.read_csv('/content/netflix.csv')

# %% [markdown]
# #Data types of dataset

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# #shape of dataset

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# #length of a dataset

# %%
len(df)
# Out:
# 8807

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# #checking null values in every column

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %% [markdown]
# Check for duplicates in dataset

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# # directors

# %%
df1_new=pd.DataFrame(df['director'].apply(lambda x:str(x).split(", ")).to_list(),index=df['title'])

# %%
df1_new
# Out:
#                                     0     1     2     3     4     5     6   \
# title
# Dick Johnson Is Dead   Kirsten Johnson  None  None  None  None  None  None
# Blood & Water                      nan  None  None  None  None  None  None
# Ganglands              Julien Leclercq  None  None  None  None  None  None
# Jailbirds New Orleans              nan  None  None  None  None  None  None
# Kota Factory                       nan  None  None  None  None  None  None
# ...                                ...   ...   ...   ...   ...   ...   ...
# Zodiac                   David Fincher  None  None  None  None  None  None
# Zombie Dumb                        nan  None  None  None  None  None  None
# Zombieland             Ruben Fleischer  None  None  None  None  None  None
# Zoom                      Peter Hewitt  None  None  None  None  None  None
# Zubaan                     Mozez Singh  None  None  None  None  None  None
#
#                          7     8     9     10    11    12
# ...

# %%
df1_new=df1_new.stack()
df1_new
# Out:
# title
# Dick Johnson Is Dead   0    Kirsten Johnson
# Blood & Water          0                nan
# Ganglands              0    Julien Leclercq
# Jailbirds New Orleans  0                nan
# Kota Factory           0                nan
#                                  ...
# Zodiac                 0      David Fincher
# Zombie Dumb            0                nan
# Zombieland             0    Ruben Fleischer
# Zoom                   0       Peter Hewitt
# Zubaan                 0        Mozez Singh
# Length: 9612, dtype: object

# %%
df1_new=pd.DataFrame(df1_new.reset_index())
df1_new
# Out:
#                       title  level_1                0
# 0      Dick Johnson Is Dead        0  Kirsten Johnson
# 1             Blood & Water        0              nan
# 2                 Ganglands        0  Julien Leclercq
# 3     Jailbirds New Orleans        0              nan
# 4              Kota Factory        0              nan
# ...                     ...      ...              ...
# 9607                 Zodiac        0    David Fincher
# 9608            Zombie Dumb        0              nan
# 9609             Zombieland        0  Ruben Fleischer
# 9610                   Zoom        0     Peter Hewitt
# 9611                 Zubaan        0      Mozez Singh
#
# [9612 rows x 3 columns]

# %%
df1_new.drop(columns=['level_1'],inplace=True)

# %%
df1_new.rename(columns={0:'Directors'},inplace=True)

# %%
df1_new.head()
# Out:
#                    title        Directors
# 0   Dick Johnson Is Dead  Kirsten Johnson
# 1          Blood & Water              nan
# 2              Ganglands  Julien Leclercq
# 3  Jailbirds New Orleans              nan
# 4           Kota Factory              nan

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# # directors

# %%
df2_new=pd.DataFrame(df['cast'].apply(lambda x:str(x).split(", ")).to_list(),index=df['title'])
df2_new
# Out:
#                                     0                1                  2   \
# title
# Dick Johnson Is Dead               nan             None               None
# Blood & Water               Ama Qamata      Khosi Ngema      Gail Mabalane
# Ganglands                Sami Bouajila     Tracy Gotoas        Samuel Jouy
# Jailbirds New Orleans              nan             None               None
# Kota Factory                Mayur More   Jitendra Kumar         Ranjan Raj
# ...                                ...              ...                ...
# Zodiac                    Mark Ruffalo  Jake Gyllenhaal  Robert Downey Jr.
# Zombie Dumb                        nan             None               None
# Zombieland             Jesse Eisenberg  Woody Harrelson         Emma Stone
# Zoom                         Tim Allen    Courteney Cox        Chevy Chase
# Zubaan                   Vicky Kaushal  Sarah-Jane Dias    Raaghav Chanana
#
# ...

# %%
df2_new=df2_new.stack()

# %%
df2_new=pd.DataFrame(df2_new.reset_index())

# %%
df2_new.head()
# Out:
#                   title  level_1               0
# 0  Dick Johnson Is Dead        0             nan
# 1         Blood & Water        0      Ama Qamata
# 2         Blood & Water        1     Khosi Ngema
# 3         Blood & Water        2   Gail Mabalane
# 4         Blood & Water        3  Thabang Molaba

# %%
df2_new.rename(columns={0:'Actors'},inplace=True)

# %%
df2_new.drop(columns={'level_1'},inplace=True)

# %%
df2_new
# Out:
#                       title                 Actors
# 0      Dick Johnson Is Dead                    nan
# 1             Blood & Water             Ama Qamata
# 2             Blood & Water            Khosi Ngema
# 3             Blood & Water          Gail Mabalane
# 4             Blood & Water         Thabang Molaba
# ...                     ...                    ...
# 64946                Zubaan       Manish Chaudhary
# 64947                Zubaan           Meghna Malik
# 64948                Zubaan          Malkeet Rauni
# 64949                Zubaan         Anita Shabdish
# 64950                Zubaan  Chittaranjan Tripathy
#
# [64951 rows x 2 columns]

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df3_new=pd.DataFrame(df['listed_in'].apply(lambda x:str(x).split(", ")).to_list(),index=df['title'])

# %%
df3_new.head()
# Out:
#                                             0                       1  \
# title
# Dick Johnson Is Dead            Documentaries                    None
# Blood & Water          International TV Shows               TV Dramas
# Ganglands                      Crime TV Shows  International TV Shows
# Jailbirds New Orleans              Docuseries              Reality TV
# Kota Factory           International TV Shows       Romantic TV Shows
#
#                                            2
# title
# Dick Johnson Is Dead                    None
# Blood & Water                   TV Mysteries
# Ganglands              TV Action & Adventure
# Jailbirds New Orleans                   None
# Kota Factory                     TV Comedies

# %%
df3_new=df3_new.stack()

# %%
df3_new=pd.DataFrame(df3_new.reset_index())

# %%
df3_new.head()
# Out:
#                   title  level_1                       0
# 0  Dick Johnson Is Dead        0           Documentaries
# 1         Blood & Water        0  International TV Shows
# 2         Blood & Water        1               TV Dramas
# 3         Blood & Water        2            TV Mysteries
# 4             Ganglands        0          Crime TV Shows

# %%
df3_new.rename(columns={0:'Genre'},inplace=True)
df3_new.drop(columns={'level_1'},inplace=True)

# %%
df3_new.head()
# Out:
#                   title                   Genre
# 0  Dick Johnson Is Dead           Documentaries
# 1         Blood & Water  International TV Shows
# 2         Blood & Water               TV Dramas
# 3         Blood & Water            TV Mysteries
# 4             Ganglands          Crime TV Shows

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# #country

# %%
df4_new=pd.DataFrame(df['country'].apply(lambda x:str(x).split(", ")).to_list(),index=df['title'])

# %%
df4_new=df4_new.stack()
df4_new=pd.DataFrame(df4_new.reset_index())

# %%
df4_new.head()
# Out:
#                    title  level_1              0
# 0   Dick Johnson Is Dead        0  United States
# 1          Blood & Water        0   South Africa
# 2              Ganglands        0            nan
# 3  Jailbirds New Orleans        0            nan
# 4           Kota Factory        0          India

# %%
df4_new.rename(columns={0:'Country'},inplace=True)
df4_new.drop(columns=['level_1'],inplace=True)

# %%
df4_new.head()
# Out:
#                    title        Country
# 0   Dick Johnson Is Dead  United States
# 1          Blood & Water   South Africa
# 2              Ganglands            nan
# 3  Jailbirds New Orleans            nan
# 4           Kota Factory          India

# %% [markdown]
# #Now merge all dataframes

# %%
df5_new=df1_new.merge(df2_new,on='title',how='inner')
df5_new.head()
# Out:
#                   title        Directors          Actors
# 0  Dick Johnson Is Dead  Kirsten Johnson             nan
# 1         Blood & Water              nan      Ama Qamata
# 2         Blood & Water              nan     Khosi Ngema
# 3         Blood & Water              nan   Gail Mabalane
# 4         Blood & Water              nan  Thabang Molaba

# %%
df6_new=df5_new.merge(df3_new,on='title',how='inner')
df6_new.head()
# Out:
#                   title        Directors       Actors                   Genre
# 0  Dick Johnson Is Dead  Kirsten Johnson          nan           Documentaries
# 1         Blood & Water              nan   Ama Qamata  International TV Shows
# 2         Blood & Water              nan   Ama Qamata               TV Dramas
# 3         Blood & Water              nan   Ama Qamata            TV Mysteries
# 4         Blood & Water              nan  Khosi Ngema  International TV Shows

# %%
df_new=df6_new.merge(df4_new,on='title',how='inner')
df_new.head()
# Out:
#                   title        Directors       Actors                   Genre  \
# 0  Dick Johnson Is Dead  Kirsten Johnson          nan           Documentaries
# 1         Blood & Water              nan   Ama Qamata  International TV Shows
# 2         Blood & Water              nan   Ama Qamata               TV Dramas
# 3         Blood & Water              nan   Ama Qamata            TV Mysteries
# 4         Blood & Water              nan  Khosi Ngema  International TV Shows
#
#          Country
# 0  United States
# 1   South Africa
# 2   South Africa
# 3   South Africa
# 4   South Africa

# %% [markdown]
# #Replacing nan values in Directors and actors

# %%
df_new['Directors'].replace(['nan'],['Unknow Director'],inplace=True)
df_new['Actors'].replace(['nan'],['Unknown Actors'],inplace=True)
# Out:
# <ipython-input-46-7cc4dcdf790d>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_new['Directors'].replace(['nan'],['Unknow Director'],inplace=True)
# <ipython-input-46-7cc4dcdf790d>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df_new['Country'].replace(['nan'],np.nan,inplace=True)
# Out:
# <ipython-input-47-38a05e39d71a>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_new['Country'].replace(['nan'],np.nan,inplace=True)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# Merge new DataFrame with old DataFrame

# %%
df_final=df_new.merge(df[['show_id','type','title','date_added','release_year','rating','duration']],on='title',how='left')

# %%
df_final
# Out:
#                        title        Directors                 Actors  \
# 0       Dick Johnson Is Dead  Kirsten Johnson         Unknown Actors
# 1              Blood & Water  Unknow Director             Ama Qamata
# 2              Blood & Water  Unknow Director             Ama Qamata
# 3              Blood & Water  Unknow Director             Ama Qamata
# 4              Blood & Water  Unknow Director            Khosi Ngema
# ...                      ...              ...                    ...
# 201986                Zubaan      Mozez Singh         Anita Shabdish
# 201987                Zubaan      Mozez Singh         Anita Shabdish
# 201988                Zubaan      Mozez Singh  Chittaranjan Tripathy
# 201989                Zubaan      Mozez Singh  Chittaranjan Tripathy
# 201990                Zubaan      Mozez Singh  Chittaranjan Tripathy
#
#                          Genre        Country show_id     type  \
# 0                Documentaries  United States      s1    Movie
# ...

# %% [markdown]
# #Check for nulls

# %%
df_final.isnull().sum()
# Out:
# title               0
# Directors           0
# Actors              0
# Genre               0
# Country         11897
# show_id             0
# type                0
# date_added        158
# release_year        0
# rating             67
# duration            3
# dtype: int64

# %% [markdown]
# #remove null duration value

# %%
df_final.loc[df_final['duration'].isnull()]
# Out:
#                                        title   Directors      Actors   Genre  \
# 126537                       Louis C.K. 2017  Louis C.K.  Louis C.K.  Movies
# 131603                 Louis C.K.: Hilarious  Louis C.K.  Louis C.K.  Movies
# 131737  Louis C.K.: Live at the Comedy Store  Louis C.K.  Louis C.K.  Movies
#
#               Country show_id   type          date_added  release_year  \
# 126537  United States   s5542  Movie       April 4, 2017          2017
# 131603  United States   s5795  Movie  September 16, 2016          2010
# 131737  United States   s5814  Movie     August 15, 2016          2015
#
#         rating duration
# 126537  74 min      NaN
# 131603  84 min      NaN
# 131737  66 min      NaN

# %%
df_final.loc[df_final['duration'].isnull(),'duration']=df_final.loc[df_final['duration'].isnull(),'duration'].fillna(df_final['rating'])

# %%
df_final.isnull().sum()
# Out:
# title               0
# Directors           0
# Actors              0
# Genre               0
# Country         11897
# show_id             0
# type                0
# date_added        158
# release_year        0
# rating             67
# duration            0
# dtype: int64

# %% [markdown]
# #Rating

# %%
df_final.loc[df_final['rating'].str.contains('min',na=False),'rating']='NR'

# %%
df_final['rating'].fillna('NR',inplace=True)
# Out:
# <ipython-input-56-497c6611c586>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_final['rating'].fillna('NR',inplace=True)

# %%
df_final.isnull().sum()
# Out:
# title               0
# Directors           0
# Actors              0
# Genre               0
# Country         11897
# show_id             0
# type                0
# date_added        158
# release_year        0
# rating              0
# duration            0
# dtype: int64

# %%
df_final.loc[df_final['date_added'].isnull()]
# Out:
#                                               title        Directors  \
# 136893  A Young Doctor's Notebook and Other Stories  Unknow Director
# 136894  A Young Doctor's Notebook and Other Stories  Unknow Director
# 136895  A Young Doctor's Notebook and Other Stories  Unknow Director
# 136896  A Young Doctor's Notebook and Other Stories  Unknow Director
# 136897  A Young Doctor's Notebook and Other Stories  Unknow Director
# ...                                             ...              ...
# 186891                 The Adventures of Figaro Pho  Unknow Director
# 186892                 The Adventures of Figaro Pho  Unknow Director
# 186893                 The Adventures of Figaro Pho  Unknow Director
# 186894                 The Adventures of Figaro Pho  Unknow Director
# 186895                 The Adventures of Figaro Pho  Unknow Director
#
#                        Actors             Genre         Country show_id  \
# ...

# %% [markdown]
# #Filling null values of date added

# %%
df_final.loc[df_final['date_added'].isnull(),'release_year'].unique()
# Out:
# array([2013, 2018, 2003, 2008, 2010, 2012, 2016, 2015])

# %%
i=2013
imp=df_final[df_final['release_year']==i]['date_added'].mode().values[0]
imp
# Out:
# 'April 9, 2019'

# %%
for i in df_final.loc[df_final['date_added'].isnull(),'release_year'].unique():
  imp=df_final[df_final['release_year']==i]['date_added'].mode().values[0]
  df_final.loc[df_final['release_year']==i,'date_added']=df_final.loc[df_final['release_year']==i,'date_added'].fillna(imp)

# %%
df_final.isnull().sum()
# Out:
# title               0
# Directors           0
# Actors              0
# Genre               0
# Country         11897
# show_id             0
# type                0
# date_added          0
# release_year        0
# rating              0
# duration            0
# dtype: int64

# %% [markdown]
# #Filling country column null values

# %%
for i in df_final[df_final['Country'].isnull()]['Directors'].unique():
  if i in df_final[~df_final['Country'].isnull()]['Directors'].unique():
    imp=df_final[df_final['Directors']==i]['Country'].mode().values[0]
    df_final.loc[df_final['Directors']==i,'Country']=df_final.loc[df_final['Directors']==i,'Country'].fillna(imp)

# %%
df_final.isnull().sum()
# Out:
# title              0
# Directors          0
# Actors             0
# Genre              0
# Country         4276
# show_id            0
# type               0
# date_added         0
# release_year       0
# rating             0
# duration           0
# dtype: int64

# %%
for i in df_final[df_final['Country'].isnull()]['Actors'].unique():
  if i in df_final[~df_final['Country'].isnull()]['Actors'].unique():
    imp=df_final[df_final['Actors']==i]['Country'].mode().values[0]
    df_final.loc[df_final['Actors']==i,'Country']=df_final.loc[df_final['Actors']==i,'Country'].fillna(imp)

# %%
df_final.isnull().sum()
# Out:
# title              0
# Directors          0
# Actors             0
# Genre              0
# Country         2069
# show_id            0
# type               0
# date_added         0
# release_year       0
# rating             0
# duration           0
# dtype: int64

# %%
df_final['Country'].replace(np.nan,'Unknown Country',inplace=True)
# Out:
# <ipython-input-67-cf364473c0a4>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_final['Country'].replace(np.nan,'Unknown Country',inplace=True)

# %%
df_final.isnull().sum()
# Out:
# title           0
# Directors       0
# Actors          0
# Genre           0
# Country         0
# show_id         0
# type            0
# date_added      0
# release_year    0
# rating          0
# duration        0
# dtype: int64

# %%
df_final.head()
# Out:
#                   title        Directors          Actors  \
# 0  Dick Johnson Is Dead  Kirsten Johnson  Unknown Actors
# 1         Blood & Water  Unknow Director      Ama Qamata
# 2         Blood & Water  Unknow Director      Ama Qamata
# 3         Blood & Water  Unknow Director      Ama Qamata
# 4         Blood & Water  Unknow Director     Khosi Ngema
#
#                     Genre        Country show_id     type          date_added  \
# 0           Documentaries  United States      s1    Movie  September 25, 2021
# 1  International TV Shows   South Africa      s2  TV Show  September 24, 2021
# 2               TV Dramas   South Africa      s2  TV Show  September 24, 2021
# 3            TV Mysteries   South Africa      s2  TV Show  September 24, 2021
# 4  International TV Shows   South Africa      s2  TV Show  September 24, 2021
#
#    release_year rating   duration
# 0          2020  PG-13     90 min
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# #Value counts and unique attributes

# %%
df_final.nunique()
# Out:
# title            8807
# Directors        4994
# Actors          36440
# Genre              42
# Country           128
# show_id          8807
# type                2
# date_added       1767
# release_year       74
# rating             14
# duration          220
# dtype: int64

# %%
df_final['title'].value_counts()
# Out:
# title
# Kahlil Gibran's The Prophet    700
# Holidays                       504
# Movie 43                       468
# The Eddy                       416
# Narcos                         378
#                               ...
# Thackeray                        1
# The 2000s                        1
# Miniforce: Super Dino Power      1
# Dancing with the Birds           1
# Dick Johnson Is Dead             1
# Name: count, Length: 8807, dtype: int64

# %%
df_final['Actors'].value_counts()
# Out:
# Actors
# Unknown Actors    2146
# Liam Neeson        161
# Alfred Molina      160
# John Krasinski     139
# Salma Hayek        130
#                   ...
# Dario Yazbek         1
# Corinne Foxx         1
# Jacob Craner         1
# Laila Berzins        1
# Richard Ryan         1
# Name: count, Length: 36440, dtype: int64

# %%
df_final['Genre'].value_counts()
# Out:
# Genre
# Dramas                          29775
# International Movies            28211
# Comedies                        20829
# International TV Shows          12845
# Action & Adventure              12216
# Independent Movies               9834
# Children & Family Movies         9771
# TV Dramas                        8942
# Thrillers                        7107
# Romantic Movies                  6412
# TV Comedies                      4963
# Crime TV Shows                   4733
# Horror Movies                    4571
# Kids' TV                         4568
# Sci-Fi & Fantasy                 4037
# Music & Musicals                 3077
# Romantic TV Shows                3049
# Documentaries                    2407
# Anime Series                     2313
# TV Action & Adventure            2288
# Spanish-Language TV Shows        2126
# British TV Shows                 1808
# Sports Movies                    1531
# Classic Movies                   1434
# ...

# %%
df_final['Directors'].value_counts()
# Out:
# Directors
# Unknow Director        50643
# Martin Scorsese          419
# Youssef Chahine          409
# Cathy Garcia-Molina      356
# Steven Spielberg         355
#                        ...
# Richard Maurice            1
# Richard E. Norman          1
# Spencer Williams           1
# Oscar Micheaux             1
# Kirsten Johnson            1
# Name: count, Length: 4994, dtype: int64

# %%
df_final['duration'].value_counts()
# Out:
# duration
# 1 Season     35035
# 2 Seasons     9559
# 3 Seasons     5084
# 94 min        4343
# 106 min       4040
#              ...
# 3 min            4
# 5 min            3
# 11 min           2
# 8 min            2
# 9 min            2
# Name: count, Length: 220, dtype: int64

# %%
df_final['duration']=df_final['duration'].str.replace('min',"")

# %%
df_final.head()
# Out:
#                   title        Directors          Actors  \
# 0  Dick Johnson Is Dead  Kirsten Johnson  Unknown Actors
# 1         Blood & Water  Unknow Director      Ama Qamata
# 2         Blood & Water  Unknow Director      Ama Qamata
# 3         Blood & Water  Unknow Director      Ama Qamata
# 4         Blood & Water  Unknow Director     Khosi Ngema
#
#                     Genre        Country show_id     type          date_added  \
# 0           Documentaries  United States      s1    Movie  September 25, 2021
# 1  International TV Shows   South Africa      s2  TV Show  September 24, 2021
# 2               TV Dramas   South Africa      s2  TV Show  September 24, 2021
# 3            TV Mysteries   South Africa      s2  TV Show  September 24, 2021
# 4  International TV Shows   South Africa      s2  TV Show  September 24, 2021
#
#    release_year rating   duration
# 0          2020  PG-13        90
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA  2 Seasons
# ...

# %%
df_final['duration'].unique()
# Out:
# array(['90 ', '2 Seasons', '1 Season', '91 ', '125 ', '9 Seasons', '104 ',
#        '127 ', '4 Seasons', '67 ', '94 ', '5 Seasons', '161 ', '61 ',
#        '166 ', '147 ', '103 ', '97 ', '106 ', '111 ', '3 Seasons', '110 ',
#        '105 ', '96 ', '124 ', '116 ', '98 ', '23 ', '115 ', '122 ', '99 ',
#        '88 ', '100 ', '6 Seasons', '102 ', '93 ', '95 ', '85 ', '83 ',
#        '113 ', '13 ', '182 ', '48 ', '145 ', '87 ', '92 ', '80 ', '117 ',
#        '128 ', '119 ', '143 ', '114 ', '118 ', '108 ', '63 ', '121 ',
#        '142 ', '154 ', '120 ', '82 ', '109 ', '101 ', '86 ', '229 ',
#        '76 ', '89 ', '156 ', '112 ', '107 ', '129 ', '135 ', '136 ',
#        '165 ', '150 ', '133 ', '70 ', '84 ', '140 ', '78 ', '7 Seasons',
#        '64 ', '59 ', '139 ', '69 ', '148 ', '189 ', '141 ', '130 ',
#        '138 ', '81 ', '132 ', '10 Seasons', '123 ', '65 ', '68 ', '66 ',
#        '62 ', '74 ', '131 ', '39 ', '46 ', '38 ', '8 Seasons',
# ...

# %%
df_final['copy_duration']=df_final['duration'].copy()

# %%
df_final.loc[df_final['copy_duration'].str.contains('Season'),'copy_duration']=0
df_final['copy_duration']=df_final['copy_duration'].astype('int')

# %% [markdown]
# #statistical summary

# %%
df_final.describe()
# Out:
#         release_year  copy_duration
# count  201991.000000  201991.000000
# mean     2013.452891      77.152789
# std         9.003933      52.269154
# min      1925.000000       0.000000
# 25%      2012.000000       0.000000
# 50%      2016.000000      95.000000
# 75%      2019.000000     112.000000
# max      2021.000000     312.000000

# %%
df_final.head()
# Out:
#                   title        Directors          Actors  \
# 0  Dick Johnson Is Dead  Kirsten Johnson  Unknown Actors
# 1         Blood & Water  Unknow Director      Ama Qamata
# 2         Blood & Water  Unknow Director      Ama Qamata
# 3         Blood & Water  Unknow Director      Ama Qamata
# 4         Blood & Water  Unknow Director     Khosi Ngema
#
#                     Genre        Country show_id     type          date_added  \
# 0           Documentaries  United States      s1    Movie  September 25, 2021
# 1  International TV Shows   South Africa      s2  TV Show  September 24, 2021
# 2               TV Dramas   South Africa      s2  TV Show  September 24, 2021
# 3            TV Mysteries   South Africa      s2  TV Show  September 24, 2021
# 4  International TV Shows   South Africa      s2  TV Show  September 24, 2021
#
#    release_year rating   duration  copy_duration
# 0          2020  PG-13        90              90
# 1          2021  TV-MA  2 Seasons              0
# ...

# %% [markdown]
# #Univariate Analysis

# %% [markdown]
#  countplot, histogram for univariate analysis

# %%
df_final.head()
# Out:
#                   title        Directors          Actors  \
# 0  Dick Johnson Is Dead  Kirsten Johnson  Unknown Actors
# 1         Blood & Water  Unknow Director      Ama Qamata
# 2         Blood & Water  Unknow Director      Ama Qamata
# 3         Blood & Water  Unknow Director      Ama Qamata
# 4         Blood & Water  Unknow Director     Khosi Ngema
#
#                     Genre        Country show_id     type          date_added  \
# 0           Documentaries  United States      s1    Movie  September 25, 2021
# 1  International TV Shows   South Africa      s2  TV Show  September 24, 2021
# 2               TV Dramas   South Africa      s2  TV Show  September 24, 2021
# 3            TV Mysteries   South Africa      s2  TV Show  September 24, 2021
# 4  International TV Shows   South Africa      s2  TV Show  September 24, 2021
#
#    release_year rating   duration  copy_duration
# 0          2020  PG-13        90              90
# 1          2021  TV-MA  2 Seasons              0
# ...

# %% [markdown]
# #Countplot for movie type

# %%
plt.figure(figsize=(16,10))
sns.countplot(df_final,x='type',color='purple')
plt.xlabel('Type')
plt.ylabel('Frequency of type')
plt.show()

# %% [markdown]
# #Countplot rating

# %%
plt.figure(figsize=(16,10))
sns.countplot(df_final,x='rating',order=df_final['rating'].value_counts().index)
plt.xlabel('Rating')
plt.ylabel('Frequency of Movie rated')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #Histogram

# %%
df_final.head()
# Out:
#                   title        Directors          Actors  \
# 0  Dick Johnson Is Dead  Kirsten Johnson  Unknown Actors
# 1         Blood & Water  Unknow Director      Ama Qamata
# 2         Blood & Water  Unknow Director      Ama Qamata
# 3         Blood & Water  Unknow Director      Ama Qamata
# 4         Blood & Water  Unknow Director     Khosi Ngema
#
#                     Genre        Country show_id     type          date_added  \
# 0           Documentaries  United States      s1    Movie  September 25, 2021
# 1  International TV Shows   South Africa      s2  TV Show  September 24, 2021
# 2               TV Dramas   South Africa      s2  TV Show  September 24, 2021
# 3            TV Mysteries   South Africa      s2  TV Show  September 24, 2021
# 4  International TV Shows   South Africa      s2  TV Show  September 24, 2021
#
#    release_year rating   duration  copy_duration
# 0          2020  PG-13        90              90
# 1          2021  TV-MA  2 Seasons              0
# ...

# %%
plt.figure(figsize=(16,10))
sns.histplot(df_final,x='release_year',bins=15)
plt.xlabel('Release Year')
plt.ylabel('Number of movies')
plt.show()

# %% [markdown]
# #KDE plot

# %%
sns.kdeplot(df_final,x='release_year')
plt.show()

# %% [markdown]
# #Bivariate Analysis

# %%
#number of distinct titles on the basis of genre
df_final.groupby('Genre').agg({'title':'nunique'})
# Out:
#                               title
# Genre
# Action & Adventure              859
# Anime Features                   71
# Anime Series                    176
# British TV Shows                253
# Children & Family Movies        641
# Classic & Cult TV                28
# Classic Movies                  116
# Comedies                       1674
# Crime TV Shows                  470
# Cult Movies                      71
# Documentaries                   869
# Docuseries                      395
# Dramas                         2427
# Faith & Spirituality             65
# Horror Movies                   357
# Independent Movies              756
# International Movies           2752
# International TV Shows         1351
# Kids' TV                        451
# Korean TV Shows                 151
# LGBTQ Movies                    102
# Movies                           57
# Music & Musicals                375
# Reality TV                      255
# Romantic Movies                 616
# ...

# %%
df_genre=df_final.groupby('Genre').agg({'title':'nunique'}).reset_index().sort_values(by=['title'],ascending=False)[:15]
df_genre
# Out:
#                        Genre  title
# 16      International Movies   2752
# 12                    Dramas   2427
# 7                   Comedies   1674
# 17    International TV Shows   1351
# 10             Documentaries    869
# 0         Action & Adventure    859
# 34                 TV Dramas    763
# 15        Independent Movies    756
# 4   Children & Family Movies    641
# 24           Romantic Movies    616
# 33               TV Comedies    581
# 41                 Thrillers    577
# 8             Crime TV Shows    470
# 18                  Kids' TV    451
# 11                Docuseries    395

# %%
plt.figure(figsize=(16,12))
sns.barplot(df_genre,x='Genre',y='title')
plt.xlabel('Genre')
plt.ylabel('Frequency of Genre')
plt.xticks(rotation=45)
plt.show()

# %%
#International Movies, Dramas and Comedies are the most popular
df_final.head()
# Out:
#                   title        Directors          Actors  \
# 0  Dick Johnson Is Dead  Kirsten Johnson  Unknown Actors
# 1         Blood & Water  Unknow Director      Ama Qamata
# 2         Blood & Water  Unknow Director      Ama Qamata
# 3         Blood & Water  Unknow Director      Ama Qamata
# 4         Blood & Water  Unknow Director     Khosi Ngema
#
#                     Genre        Country show_id     type          date_added  \
# 0           Documentaries  United States      s1    Movie  September 25, 2021
# 1  International TV Shows   South Africa      s2  TV Show  September 24, 2021
# 2               TV Dramas   South Africa      s2  TV Show  September 24, 2021
# 3            TV Mysteries   South Africa      s2  TV Show  September 24, 2021
# 4  International TV Shows   South Africa      s2  TV Show  September 24, 2021
#
#    release_year rating   duration  copy_duration
# 0          2020  PG-13        90              90
# 1          2021  TV-MA  2 Seasons              0
# ...

# %%
df_final.groupby('type').agg({'title':'nunique'})
# Out:
#          title
# type
# Movie     6131
# TV Show   2676

# %%
df_type=df_final.groupby('type').agg({'title':'nunique'}).reset_index().sort_values(by='title',ascending=False)
df_type
# Out:
#       type  title
# 0    Movie   6131
# 1  TV Show   2676

# %%
plt.figure(figsize=(16,10))
sns.barplot(df_type,x='type',y='title')
plt.xlabel('Type')
plt.ylabel('Frequency of Type')
plt.xticks(rotation=45)
plt.show()

# %%
#number of distinct titles on the basis of country
df_final.groupby('Country').agg({'title':'nunique'})
# Out:
#               title
# Country
#                   3
# Afghanistan       1
# Albania           1
# Algeria           3
# Angola            2
# ...             ...
# Vatican City      1
# Venezuela         4
# Vietnam           7
# West Germany      5
# Zimbabwe          3
#
# [128 rows x 1 columns]

# %%
df_country=df_final.groupby('Country').agg({'title':'nunique'}).reset_index().sort_values(by='title',ascending=False)[:15]
plt.figure(figsize=(16,10))
sns.barplot(df_country,x='Country',y='title')
plt.xlabel('Country')
plt.ylabel('Frequency of title')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# US,India,United Kingdom,Canada and France are top 5 netflix content viewers

# %% [markdown]
# ##number of distinct titles on the basis of Actors

# %%
df_final.groupby('Actors').agg({'title':'nunique'})
# Out:
#                        title
# Actors
#  Jr.                       2
# "Riley" Lakdhar Dridi      1
# 'Najite Dede               2
# 2 Chainz                   1
# 2Mex                       1
# ...                      ...
# Şevket Çoruh               1
# Şinasi Yurtsever           3
# Şükran Ovalı               1
# Şükrü Özyıldız             2
# Ṣọpẹ́ Dìrísù               1
#
# [36440 rows x 1 columns]

# %%
df_actors=df_final.groupby('Actors').agg({'title':'nunique'}).reset_index().sort_values(by='title',ascending=False)
df_actors=df_actors[df_actors['Actors']!='Unknown Actors'][:15]
plt.figure(figsize=(16,10))
sns.barplot(df_actors,x='Actors',y='title',color='indigo')
plt.xlabel('Actors')
plt.ylabel('Frequency of titles')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #number of distinct titles on the basis of Directors

# %%
df_directors=df_final.groupby('Directors').agg({'title':'nunique'}).reset_index().sort_values(by='title',ascending=False)
df_directors=df_directors[df_directors['Directors']!='Unknow Director'][:15]
plt.figure(figsize=(16,8))
sns.barplot(df_directors,x='Directors',y='title')
plt.xlabel('Directors')
plt.ylabel('Popular directors')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #Line PLot

# %% [markdown]
# #number of distinct titles on the basis of year

# %%
df_final.head()
# Out:
#                   title        Directors          Actors  \
# 0  Dick Johnson Is Dead  Kirsten Johnson  Unknown Actors
# 1         Blood & Water  Unknow Director      Ama Qamata
# 2         Blood & Water  Unknow Director      Ama Qamata
# 3         Blood & Water  Unknow Director      Ama Qamata
# 4         Blood & Water  Unknow Director     Khosi Ngema
#
#                     Genre        Country show_id     type          date_added  \
# 0           Documentaries  United States      s1    Movie  September 25, 2021
# 1  International TV Shows   South Africa      s2  TV Show  September 24, 2021
# 2               TV Dramas   South Africa      s2  TV Show  September 24, 2021
# 3            TV Mysteries   South Africa      s2  TV Show  September 24, 2021
# 4  International TV Shows   South Africa      s2  TV Show  September 24, 2021
#
#    release_year rating   duration  copy_duration
# 0          2020  PG-13        90              90
# 1          2021  TV-MA  2 Seasons              0
# ...

# %%
df_year=df_final.groupby('release_year').agg({'title':'nunique'}).reset_index().sort_values(by='title',ascending=False)
plt.figure(figsize=(16,8))
sns.lineplot(df_year,x='release_year',y='title')
plt.xlabel('Year')
plt.ylabel('Movies')
plt.show()

# %% [markdown]
# #Movies released after 1980

# %%
df_release_year=df_final[df_final['release_year']>=1980].groupby(['release_year']).agg({"title":"nunique"}).reset_index()
sns.lineplot(data=df_release_year, x='release_year', y='title')
plt.ylabel("Movies Actual Release Date")
plt.xlabel("Year")
plt.show()

# %% [markdown]
# due to covid in 2020 there is a drop in movie release

# %% [markdown]
# #Box Plots

# %%
df_final.head()
# Out:
#                   title        Directors          Actors  \
# 0  Dick Johnson Is Dead  Kirsten Johnson  Unknown Actors
# 1         Blood & Water  Unknow Director      Ama Qamata
# 2         Blood & Water  Unknow Director      Ama Qamata
# 3         Blood & Water  Unknow Director      Ama Qamata
# 4         Blood & Water  Unknow Director     Khosi Ngema
#
#                     Genre        Country show_id     type          date_added  \
# 0           Documentaries  United States      s1    Movie  September 25, 2021
# 1  International TV Shows   South Africa      s2  TV Show  September 24, 2021
# 2               TV Dramas   South Africa      s2  TV Show  September 24, 2021
# 3            TV Mysteries   South Africa      s2  TV Show  September 24, 2021
# 4  International TV Shows   South Africa      s2  TV Show  September 24, 2021
#
#    release_year rating   duration  copy_duration
# 0          2020  PG-13        90              90
# 1          2021  TV-MA  2 Seasons              0
# ...

# %%
df_final['type'].value_counts()
# Out:
# type
# Movie      145843
# TV Show     56148
# Name: count, dtype: int64

# %%
#let's plot boxplot

# %%
df_final.head()
# Out:
#                   title        Directors          Actors  \
# 0  Dick Johnson Is Dead  Kirsten Johnson  Unknown Actors
# 1         Blood & Water  Unknow Director      Ama Qamata
# 2         Blood & Water  Unknow Director      Ama Qamata
# 3         Blood & Water  Unknow Director      Ama Qamata
# 4         Blood & Water  Unknow Director     Khosi Ngema
#
#                     Genre        Country show_id     type          date_added  \
# 0           Documentaries  United States      s1    Movie  September 25, 2021
# 1  International TV Shows   South Africa      s2  TV Show  September 24, 2021
# 2               TV Dramas   South Africa      s2  TV Show  September 24, 2021
# 3            TV Mysteries   South Africa      s2  TV Show  September 24, 2021
# 4  International TV Shows   South Africa      s2  TV Show  September 24, 2021
#
#    release_year rating   duration  copy_duration
# 0          2020  PG-13        90              90
# 1          2021  TV-MA  2 Seasons              0
# ...

# %%
plt.figure(figsize=(16,10))
sns.boxplot(df_final,x='type',y='copy_duration')
plt.xlabel('Type')
plt.ylabel('Duration')
plt.show()

# %% [markdown]
# #Let's analyze for shows and movies of United States and India

# %%
df_final.head()
# Out:
#                   title        Directors          Actors  \
# 0  Dick Johnson Is Dead  Kirsten Johnson  Unknown Actors
# 1         Blood & Water  Unknow Director      Ama Qamata
# 2         Blood & Water  Unknow Director      Ama Qamata
# 3         Blood & Water  Unknow Director      Ama Qamata
# 4         Blood & Water  Unknow Director     Khosi Ngema
#
#                     Genre        Country show_id     type          date_added  \
# 0           Documentaries  United States      s1    Movie  September 25, 2021
# 1  International TV Shows   South Africa      s2  TV Show  September 24, 2021
# 2               TV Dramas   South Africa      s2  TV Show  September 24, 2021
# 3            TV Mysteries   South Africa      s2  TV Show  September 24, 2021
# 4  International TV Shows   South Africa      s2  TV Show  September 24, 2021
#
#    release_year rating   duration  copy_duration
# 0          2020  PG-13        90              90
# 1          2021  TV-MA  2 Seasons              0
# ...

# %% [markdown]
# Rating for unique movies in USA

# %%
df_c=df_final[df_final['Country']=='United States']
df_mov=df_c[df_c['type']=='Movie']
df_mov
# Out:
#                                    title        Directors           Actors  \
# 0                   Dick Johnson Is Dead  Kirsten Johnson   Unknown Actors
# 159     My Little Pony: A New Generation    Robert Cullen  Vanessa Hudgens
# 160     My Little Pony: A New Generation    Robert Cullen     Kimiko Glenn
# 161     My Little Pony: A New Generation    Robert Cullen    James Marsden
# 162     My Little Pony: A New Generation    Robert Cullen     Sofia Carson
# ...                                  ...              ...              ...
# 201962                              Zoom     Peter Hewitt  Spencer Breslin
# 201963                              Zoom     Peter Hewitt         Rip Torn
# 201964                              Zoom     Peter Hewitt         Rip Torn
# 201965                              Zoom     Peter Hewitt     Kevin Zegers
# 201966                              Zoom     Peter Hewitt     Kevin Zegers
#
#                            Genre        Country show_id   type  \
# ...

# %%
df_rating=df_mov.groupby('rating').agg({'title':'nunique'}).reset_index().sort_values(by='title',ascending=False)[:15]

# %%
plt.figure(figsize=(16,10))
sns.barplot(df_rating,x='rating',y='title',color='grey')
plt.xlabel('Rating')
plt.ylabel('Number of Movies')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #Rating for unique TVshows in USA

# %%
df_c=df_final[df_final['Country']=='United States']
df_tv=df_c[df_c['type']=='TV Show']

# %%
df_rating=df_tv.groupby('rating').agg({'title':'nunique'}).reset_index().sort_values(by='title')

# %%
plt.figure(figsize=(16,10))
sns.barplot(df_rating,x='rating',y='title',color='grey')
plt.xlabel('rating')
plt.ylabel('Number of Tv shows')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# India TV shows and Movies

# %%
df_final.sample(5)
# Out:
#                              title                  Directors  \
# 143770                  Borderline            Unknow Director
# 142031                     Bewafaa           Dharmesh Darshan
# 174937                      Ottaal  Jayaraj Rajasekharan Nair
# 105714  Violet Evergarden: Special            Unknow Director
# 6335                       Unroyal               Moses Inwang
#
#                      Actors                   Genre         Country show_id  \
# 143770          David Avery        British TV Shows  United Kingdom   s6362
# 142031           Kabir Bedi         Romantic Movies           India   s6290
# 174937  Kumarakom Vasudevan    International Movies           India   s7683
# 105714       Haruka Tomatsu  International TV Shows   United States   s4537
# 6335           Femi Adebayo    International Movies         Nigeria    s269
#
#            type         date_added  release_year rating   duration  \
# ...

# %% [markdown]
# Number of movies released in each year in india

# %%
df_c=df_final[df_final['Country']=='India']
df_mov=df_c[df_c['type']=='Movie']

# %%
df_year=df_mov.groupby('release_year').agg({'title':'nunique'}).reset_index().sort_values(by='title',ascending=False)[:7]

# %%
plt.figure(figsize=(16,10))
sns.barplot(df_year,x='release_year',y='title')
plt.xlabel('Release Year')
plt.ylabel('Number of movies')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #Number of TVshow released in each year in india using line plot

# %%
df_c=df_final[df_final['Country']=='India']
df_show=df_c[df_c['type']=='TV Show']

# %%
df_year=df.groupby('release_year').agg({'title':'nunique'}).reset_index().sort_values(by='title',ascending=False)

# %%
plt.figure(figsize=(16,10))
sns.lineplot(df_year,x='release_year',y='title')
plt.xlabel('Release Year')
plt.ylabel('Number of movies')
plt.show()

# %%
df_final
# Out:
#                        title        Directors                 Actors  \
# 0       Dick Johnson Is Dead  Kirsten Johnson         Unknown Actors
# 1              Blood & Water  Unknow Director             Ama Qamata
# 2              Blood & Water  Unknow Director             Ama Qamata
# 3              Blood & Water  Unknow Director             Ama Qamata
# 4              Blood & Water  Unknow Director            Khosi Ngema
# ...                      ...              ...                    ...
# 201986                Zubaan      Mozez Singh         Anita Shabdish
# 201987                Zubaan      Mozez Singh         Anita Shabdish
# 201988                Zubaan      Mozez Singh  Chittaranjan Tripathy
# 201989                Zubaan      Mozez Singh  Chittaranjan Tripathy
# 201990                Zubaan      Mozez Singh  Chittaranjan Tripathy
#
#                          Genre        Country show_id     type  \
# 0                Documentaries  United States      s1    Movie
# ...

# %% [markdown]
# #Multi Variate Analysis

# %%
df_u=df_final[(df_final['Country']=='United States')|(df_final['Country']=='India')|(df_final['Country']=='Japan')]
df_u
# Out:
#                         title        Directors                 Actors  \
# 0        Dick Johnson Is Dead  Kirsten Johnson         Unknown Actors
# 85      Jailbirds New Orleans  Unknow Director         Unknown Actors
# 86      Jailbirds New Orleans  Unknow Director         Unknown Actors
# 87               Kota Factory  Unknow Director             Mayur More
# 88               Kota Factory  Unknow Director             Mayur More
# ...                       ...              ...                    ...
# 201986                 Zubaan      Mozez Singh         Anita Shabdish
# 201987                 Zubaan      Mozez Singh         Anita Shabdish
# 201988                 Zubaan      Mozez Singh  Chittaranjan Tripathy
# 201989                 Zubaan      Mozez Singh  Chittaranjan Tripathy
# 201990                 Zubaan      Mozez Singh  Chittaranjan Tripathy
#
#                          Genre        Country show_id     type  \
# ...

# %%
df_final['Genre'].value_counts()
# Out:
# Genre
# Dramas                          29775
# International Movies            28211
# Comedies                        20829
# International TV Shows          12845
# Action & Adventure              12216
# Independent Movies               9834
# Children & Family Movies         9771
# TV Dramas                        8942
# Thrillers                        7107
# Romantic Movies                  6412
# TV Comedies                      4963
# Crime TV Shows                   4733
# Horror Movies                    4571
# Kids' TV                         4568
# Sci-Fi & Fantasy                 4037
# Music & Musicals                 3077
# Romantic TV Shows                3049
# Documentaries                    2407
# Anime Series                     2313
# TV Action & Adventure            2288
# Spanish-Language TV Shows        2126
# British TV Shows                 1808
# Sports Movies                    1531
# Classic Movies                   1434
# ...

# %%
df_h=df_u[(df_u['Genre']=='Horror Movies')|(df_u['Genre']=='Romantic Movies')|(df_u['Genre']=='Thrillers')]
df_h
# Out:
#              title        Directors                  Actors            Genre  \
# 555      Intrusion       Adam Salky    Logan Marshall-Green        Thrillers
# 560      Intrusion       Adam Salky          Mark Sivertsen        Thrillers
# 643          Jeans       S. Shankar               Prashanth  Romantic Movies
# 646          Jeans       S. Shankar  Aishwarya Rai Bachchan  Romantic Movies
# 649          Jeans       S. Shankar             Sri Lakshmi  Romantic Movies
# ...            ...              ...                     ...              ...
# 201940  Zombieland  Ruben Fleischer              Emma Stone    Horror Movies
# 201942  Zombieland  Ruben Fleischer         Abigail Breslin    Horror Movies
# 201944  Zombieland  Ruben Fleischer             Amber Heard    Horror Movies
# 201946  Zombieland  Ruben Fleischer             Bill Murray    Horror Movies
# 201948  Zombieland  Ruben Fleischer              Derek Graf    Horror Movies
#
# ...

# %%
# sum of duration of movies
plt.figure(figsize=(16,10))
sns.barplot(df_h,x='Country',y='copy_duration',hue='Genre',estimator=np.sum)
plt.xlabel('Country')
plt.ylabel('Duration of movie')
plt.show()

# %%
#avg duration of movies
plt.figure(figsize=(16,10))
sns.barplot(df_h,x='Country',y='copy_duration',hue='Genre',estimator=np.mean)
plt.xlabel('Country')
plt.ylabel('avg duration')
plt.show()

# %% [markdown]
# #Boxplot for Multi Variate

# %%
df_h.head()
# Out:
#          title   Directors                  Actors            Genre  \
# 555  Intrusion  Adam Salky    Logan Marshall-Green        Thrillers
# 560  Intrusion  Adam Salky          Mark Sivertsen        Thrillers
# 643      Jeans  S. Shankar               Prashanth  Romantic Movies
# 646      Jeans  S. Shankar  Aishwarya Rai Bachchan  Romantic Movies
# 649      Jeans  S. Shankar             Sri Lakshmi  Romantic Movies
#
#            Country show_id   type          date_added  release_year rating  \
# 555  United States     s19  Movie  September 22, 2021          2021  TV-14
# 560  United States     s19  Movie  September 22, 2021          2021  TV-14
# 643          India     s25  Movie  September 21, 2021          1998  TV-14
# 646          India     s25  Movie  September 21, 2021          1998  TV-14
# 649          India     s25  Movie  September 21, 2021          1998  TV-14
#
#     duration  copy_duration
# 555      94              94
# 560      94              94
# ...

# %%
plt.figure(figsize=(16,10))
sns.boxplot(df_h,x='Country',y='copy_duration',hue='Genre')
plt.xlabel('Country')
plt.ylabel('Duration')
plt.show()

# %% [markdown]
# #For correlation Heatmaps, Pairplots

# %%
df_final.head()
# Out:
#                   title        Directors          Actors  \
# 0  Dick Johnson Is Dead  Kirsten Johnson  Unknown Actors
# 1         Blood & Water  Unknow Director      Ama Qamata
# 2         Blood & Water  Unknow Director      Ama Qamata
# 3         Blood & Water  Unknow Director      Ama Qamata
# 4         Blood & Water  Unknow Director     Khosi Ngema
#
#                     Genre        Country show_id     type          date_added  \
# 0           Documentaries  United States      s1    Movie  September 25, 2021
# 1  International TV Shows   South Africa      s2  TV Show  September 24, 2021
# 2               TV Dramas   South Africa      s2  TV Show  September 24, 2021
# 3            TV Mysteries   South Africa      s2  TV Show  September 24, 2021
# 4  International TV Shows   South Africa      s2  TV Show  September 24, 2021
#
#    release_year rating   duration  copy_duration
# 0          2020  PG-13        90              90
# 1          2021  TV-MA  2 Seasons              0
# ...

# %%
df_final.select_dtypes([float,int]).corr()
# Out:
#                release_year  copy_duration
# release_year       1.000000      -0.303529
# copy_duration     -0.303529       1.000000

# %%
sns.heatmap(df_final.select_dtypes([float,int]).corr())
# Out:
# <Axes: >

# %% [markdown]
# #Pair Plot

# %%
numeric_cols=['release_year','copy_duration']

# %%
sns.pairplot(df_final[numeric_cols])
